# %% [markdown]
# # Introduction au Machine Learning
# ## Découverte des algorithmes fondamentaux
#
# Objectifs du notebook :
# - Comprendre ce qu’est le machine learning
# - Manipuler des algorithmes supervisés et non supervisés
# - Observer l’impact des hyperparamètres
# - Apprendre à évaluer un modèle

# %%
# Import des bibliothèques
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1. Chargement des données
#
# Nous utilisons le jeu de données Iris.
# Il contient :
# - 150 observations
# - 4 variables numériques
# - 3 classes de fleurs

# %%
# Charger les données
data = load_iris()

X = data.data
y = data.target

# QUESTION :
# Afficher la forme de X
# Indice : utiliser .shape

# X.shape

# %% [markdown]
# ## 2. Séparation train / test
# On sépare les données pour évaluer la généralisation du modèle.

# %%
# Séparer les données
# Compléter les parties manquantes

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=...,        # indice : 0.2
    random_state=...
)

# %% [markdown]
# ## 3. Standardisation des données
#
# Certains algorithmes (k-NN, SVM, k-means) sont sensibles à l’échelle.

# %%
scaler = StandardScaler()

# Compléter :
# X_train_scaled =
# X_test_scaled =

# %% [markdown]
# ## 4. Classification avec k-NN
# Algorithme supervisé basé sur la similarité.

# %%
from sklearn.neighbors import KNeighborsClassifier

# Choisir k
k = ...  # indice : 3 ou 5

model_knn = KNeighborsClassifier(n_neighbors=k)

# Entraîner le modèle
# model_knn.fit(...)

# Prédictions
# y_pred =

# %% [markdown]
# ## 5. Évaluation du modèle

# %%
from sklearn.metrics import accuracy_score

# Calculer l'accuracy
# accuracy =
# print(accuracy)

# %% [markdown]
# ## 6. Clustering non supervisé avec k-means
# Ici, on n’utilise pas les labels.

# %%
from sklearn.cluster import KMeans

k = ...  # nombre de clusters

kmeans = KMeans(n_clusters=k, random_state=42)

# Apprendre les clusters
# kmeans.fit(...)

# Labels prédits
# clusters =

# %% [markdown]
# ## 7. Réduction de dimension avec ACP
# Visualisation en 2D.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

# X_pca =

# %% [markdown]
# ## Conclusion
#
# Vous avez :
# - utilisé un algorithme supervisé (k-NN)
# - utilisé un algorithme non supervisé (k-means)
# - réduit la dimension avec l’ACP
#
# Compléter les parties manquantes et observer les résultats.
